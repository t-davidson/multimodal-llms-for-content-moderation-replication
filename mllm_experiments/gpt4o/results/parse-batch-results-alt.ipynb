# %%
import json
import glob
import pandas as pd

# %%
files = glob.glob("batch_result_*")

# %%
files = [x for x in files if "alt" in x]

# %%
files = files[1:]

# %% [markdown]
# Ignoring first version using indexing.

# %%
# Initialize an empty list to store the data
data = []

# Iterate through each file
for file in files:
    with open(file, 'r') as f:
        # Read each line as a JSON object
        for line in f:
            record = json.loads(line)
            # Add the filename as a new field
            record['source_file'] = file

            # Extract 'content' and 'refusal' from the 'choices' list if available
            if 'response' in record and 'body' in record['response'] and 'choices' in record['response']['body']:
                choices = record['response']['body']['choices']
                if choices and isinstance(choices, list):
                    # We assume there is at least one choice; you could add further checks here
                    record['content'] = choices[0]['message'].get('content', None)
                    record['refusal'] = choices[0]['message'].get('refusal', None)

            # Append the record to the data list
            data.append(record)

# Create a pandas dataframe from the list of dictionaries
df = pd.json_normalize(data)
# Out:
#                                            id  custom_id error  \
# 0  batch_req_682d1e05841081908aab5daf157bf874  request-1  None
# 1  batch_req_682d1e05adfc81909a6ea36e400a42d9  request-2  None
# 2  batch_req_682d1e05d1b081908019144979064fc4  request-3  None
# 3  batch_req_682d1e05f1b0819089526e3de3ccf1bb  request-4  None
# 4  batch_req_682d1e06176081908104c693603fbbd3  request-5  None
#
#                                          source_file content refusal  \
# 0  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       B    None
# 1  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A    None
# 2  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A    None
# 3  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A    None
# 4  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       B    None
#
#    response.status_code               response.request_id  \
# 0                   200  6089970e413090275885687ea91082ed
# 1                   200  91af04b12aa9b871d5463eef65af22c0
# 2                   200  a91bb0868dc76d2a4f35506530d133bd
# 3                   200  6861f98f50b085400fdb7f38c196de62
# 4                   200  88abeb1a6e9cfc26b56c00f0033affd8
#
#                          response.body.id response.body.object  ...  \
# 0  chatcmpl-BZQ86rtKdRig9f1MkXIxNiT7oavA1      chat.completion  ...
# 1  chatcmpl-BZQAvMRt4mAYYRJiXc9k20KrflTpg      chat.completion  ...
# 2  chatcmpl-BZQBDS81l7nQjwixAmzYbt8HxXstE      chat.completion  ...
# 3  chatcmpl-BZQAwZFemhT4irD9QqptLR7dGuoaM      chat.completion  ...
# 4  chatcmpl-BZQAwRuzlkoYF3TdK9Ht5NquJFRO5      chat.completion  ...
#
#    response.body.usage.completion_tokens response.body.usage.total_tokens  \
# 0                                      1                             1366
# 1                                      1                             1876
# 2                                      1                             2386
# 3                                      1                             2386
# 4                                      1                             1876
#
#   response.body.usage.prompt_tokens_details.cached_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.usage.prompt_tokens_details.audio_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.usage.completion_tokens_details.reasoning_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.usage.completion_tokens_details.audio_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.usage.completion_tokens_details.accepted_prediction_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.usage.completion_tokens_details.rejected_prediction_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.service_tier  response.body.system_fingerprint
# 0                     default                     fp_b7faba9ef5
# 1                     default                     fp_b7faba9ef5
# 2                     default                     fp_b7faba9ef5
# 3                     default                     fp_b7faba9ef5
# 4                     default                     fp_b7faba9ef5
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (199500, 24)

# %% [markdown]
# Now merging in the image IDs that correspond to the request numbers. To do this, starting by creating a numeric ID vector, then using this to merge with `df`. Requests were coded numerically from one upwards.

# %%
image_numbers = pd.read_csv("../image_indices_alt_99750.csv")

# %%
image_numbers['custom_id'] = [f"request-{i}" for i in range(1, 99751)]

# %%
image_numbers.shape
# Out:
# (99750, 6)

# %%
image_numbers.head()
# Out:
#    Unnamed: 0  a_images  b_images                     a_paths  \
# 0           0    555755    183551  output_alt/tweet585754.png
# 1           1    419943    440191  output_alt/tweet449942.png
# 2           2    497331    251346  output_alt/tweet527330.png
# 3           3     32817    110536  output_2024/tweet32817.png
# 4           4    224661    460665  output_alt/tweet254660.png
#
#                        b_paths  custom_id
# 0  output_2024/tweet183551.png  request-1
# 1   output_alt/tweet470190.png  request-2
# 2   output_alt/tweet281345.png  request-3
# 3  output_2024/tweet110536.png  request-4
# 4   output_alt/tweet490664.png  request-5

# %%
merged_df = pd.merge(df, image_numbers, on='custom_id', how='left')

# %%
merged_df.head()
# Out:
#                                            id  custom_id error  \
# 0  batch_req_682d1e05841081908aab5daf157bf874  request-1  None
# 1  batch_req_682d1e05adfc81909a6ea36e400a42d9  request-2  None
# 2  batch_req_682d1e05d1b081908019144979064fc4  request-3  None
# 3  batch_req_682d1e05f1b0819089526e3de3ccf1bb  request-4  None
# 4  batch_req_682d1e06176081908104c693603fbbd3  request-5  None
#
#                                          source_file content refusal  \
# 0  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       B    None
# 1  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A    None
# 2  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A    None
# 3  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A    None
# 4  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       B    None
#
#    response.status_code               response.request_id  \
# 0                   200  6089970e413090275885687ea91082ed
# 1                   200  91af04b12aa9b871d5463eef65af22c0
# 2                   200  a91bb0868dc76d2a4f35506530d133bd
# 3                   200  6861f98f50b085400fdb7f38c196de62
# 4                   200  88abeb1a6e9cfc26b56c00f0033affd8
#
#                          response.body.id response.body.object  ...  \
# 0  chatcmpl-BZQ86rtKdRig9f1MkXIxNiT7oavA1      chat.completion  ...
# 1  chatcmpl-BZQAvMRt4mAYYRJiXc9k20KrflTpg      chat.completion  ...
# 2  chatcmpl-BZQBDS81l7nQjwixAmzYbt8HxXstE      chat.completion  ...
# 3  chatcmpl-BZQAwZFemhT4irD9QqptLR7dGuoaM      chat.completion  ...
# 4  chatcmpl-BZQAwRuzlkoYF3TdK9Ht5NquJFRO5      chat.completion  ...
#
#    response.body.usage.completion_tokens_details.audio_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   response.body.usage.completion_tokens_details.accepted_prediction_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   response.body.usage.completion_tokens_details.rejected_prediction_tokens  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    response.body.service_tier  response.body.system_fingerprint  Unnamed: 0  \
# 0                     default                     fp_b7faba9ef5           0
# 1                     default                     fp_b7faba9ef5           1
# 2                     default                     fp_b7faba9ef5           2
# 3                     default                     fp_b7faba9ef5           3
# 4                     default                     fp_b7faba9ef5           4
#
#    a_images  b_images                     a_paths                      b_paths
# 0    555755    183551  output_alt/tweet585754.png  output_2024/tweet183551.png
# 1    419943    440191  output_alt/tweet449942.png   output_alt/tweet470190.png
# 2    497331    251346  output_alt/tweet527330.png   output_alt/tweet281345.png
# 3     32817    110536  output_2024/tweet32817.png  output_2024/tweet110536.png
# 4    224661    460665  output_alt/tweet254660.png   output_alt/tweet490664.png
#
# [5 rows x 29 columns]

# %%
merged_df_ = merged_df[["source_file", "content", "response.body.usage.prompt_tokens", "a_images", "b_images", "a_paths", "b_paths"]]

# %%
merged_df_.shape
# Out:
# (199500, 7)

# %%
merged_df_.head()
# Out:
#                                          source_file content  \
# 0  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       B
# 1  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A
# 2  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A
# 3  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       A
# 4  batch_result_baseline_alt_GPT4o_combined_v2.jsonl       B
#
#    response.body.usage.prompt_tokens  a_images  b_images  \
# 0                               1365    555755    183551
# 1                               1875    419943    440191
# 2                               2385    497331    251346
# 3                               2385     32817    110536
# 4                               1875    224661    460665
#
#                       a_paths                      b_paths
# 0  output_alt/tweet585754.png  output_2024/tweet183551.png
# 1  output_alt/tweet449942.png   output_alt/tweet470190.png
# 2  output_alt/tweet527330.png   output_alt/tweet281345.png
# 3  output_2024/tweet32817.png  output_2024/tweet110536.png
# 4  output_alt/tweet254660.png   output_alt/tweet490664.png

# %%
merged_df_ = merged_df_.assign(
    model=lambda df: df["source_file"].apply(lambda x: "mini" if "mini" in x else "base"),
    prompt=lambda df: df["source_file"].apply(lambda x: x.split("_")[2] if len(x.split("_")) > 2 else None)
)

# %%
merged_df_.tail()
# Out:
#                                               source_file content  \
# 199495  batch_result_baseline_alt_GPT4o_mini_combined....       B
# 199496  batch_result_baseline_alt_GPT4o_mini_combined....       B
# 199497  batch_result_baseline_alt_GPT4o_mini_combined....       B
# 199498  batch_result_baseline_alt_GPT4o_mini_combined....       A
# 199499  batch_result_baseline_alt_GPT4o_mini_combined....       A
#
#         response.body.usage.prompt_tokens  a_images  b_images  \
# 199495                              73845    565266    218822
# 199496                              56844    494672    439779
# 199497                              73845    318998    517816
# 199498                              73845    248397     97965
# 199499                              56844    347662     11343
#
#                            a_paths                     b_paths model    prompt
# 199495  output_alt/tweet595265.png  output_alt/tweet248821.png  mini  baseline
# 199496  output_alt/tweet524671.png  output_alt/tweet469778.png  mini  baseline
# 199497  output_alt/tweet348997.png  output_alt/tweet547815.png  mini  baseline
# 199498  output_alt/tweet278396.png  output_2024/tweet97965.png  mini  baseline
# 199499  output_alt/tweet377661.png  output_2024/tweet11343.png  mini  baseline

# %% [markdown]
# Verifying that we have 30k rows for each combination of model and prompt.

# %%
merged_df_.groupby(["model", "prompt"]).size().reset_index(name="count")
# Out:
#   model    prompt  count
# 0  base  baseline  99750
# 1  mini  baseline  99750

# %%
merged_df_.to_csv("gpt4o-experiments-results-alt.csv")
